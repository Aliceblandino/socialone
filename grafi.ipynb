# %% [markdown]
# # Progetto social
# ## Realizzazione di grafi riguardanti le pubblicazioni degli articoli del dipartimento scientifico
# Ricerca tramite piattaforma Scopus di pubblicazioni di articoli scientifici dell'università di udine e analisi dei dati.
# ### Analisi del dataset
# Caricamento dataset e valutazione attendibilità dei paramtri

# %%
# Lista delle librerie da controllare
import importlib
import subprocess
import sys

# Dizionario: nome_pip -> nome_import
required_packages = {
    "pandas": "pandas",
    "networkx": "networkx",
    "pyvis": "pyvis",
    "matplotlib": "matplotlib",
    "numpy": "numpy",
    "plotly": "plotly",
    "ipython": "IPython",
    "scipy": "scipy"
}

for pip_name, import_name in required_packages.items():
    try:
        importlib.import_module(import_name)
        print(f"{pip_name} già installato ✅")
    except ImportError:
        print(f"{pip_name} non trovato. Installazione in corso...")
        subprocess.check_call(
            [sys.executable, "-m", "pip", "install", pip_name]
        )
        print(f"{pip_name} installato correttamente ✅")
# Out:
# pandas già installato ✅
# networkx già installato ✅
# pyvis già installato ✅
# matplotlib già installato ✅
# numpy già installato ✅
# plotly già installato ✅
# ipython già installato ✅
# scipy già installato ✅

# %%
import pandas as pd
import networkx as nx
from pyvis.network import Network
from collections import Counter
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import numpy as np
import os
from IPython.display import display
import itertools
import plotly.graph_objects as go
import scipy

# %%
#caricamento dataset grezzo
df=pd.read_csv('dataset.csv')
df.head()
# Out:
#                                              Authors  \
# 0                           Lancia, G.; Dalpasso, M.
# 1  Da Ros, F.; Di Gaspero, L.; Kletzander, L.; La...
# 2  Bacchetti, E.; de Nardin, A.; Giannarini, G.; ...
# 3  Ozkilinc, O.; Soler, M.A.; Giannozzi, P.; Apar...
# 4              Faletič, S.; Micheli, M.; Pospiec, G.
#
#                                    Author full names  \
# 0  Lancia, Giuseppe G. (6701584197); Dalpasso, Ma...
# 1  Da Ros, Francesca (58134137500); Di Gaspero, L...
# 2  Bacchetti, Emiliano (59995162800); de Nardin, ...
# 3  Ozkilinc, Ozge (58138235700); Soler, Miguel A....
# 4  Faletič, Sergej (56595108900); Micheli, Marisa...
#
#                                         Author(s) ID  \
# 0                             6701584197; 6603897248
# 1  58134137500; 6505944235; 57194560339; 57188717...
# 2  59995162800; 57259162600; 55883317500; 2448058...
# 3  58138235700; 8718855800; 7004488307; 572046647...
# 4              56595108900; 59664609000; 59665606800
#
#                                                Title  Year  \
# 0  Speeding Up Floyd–Warshall’s Algorithm to Comp...  2025
# 1  Dynamic Temperature Control of Simulated Annea...  2025
# 2  A Deep Learning Model Integrating Clinical and...  2025
# 3  The Single-Parameter Bragg–Williams Model for ...  2025
# 4  Teaching and learning quantum entanglement: a ...  2025
#
#                                   Source title Volume Issue Art. No.  \
# 0                                   Algorithms     18     9      560
# 1                                          NaN    NaN   NaN      NaN
# 2                                      Cancers     17    13     2257
# 3  International Journal of Molecular Sciences     26     3      997
# 4        Journal of Physics: Conference Series   2950     1   012025
#
#   Page start  ...                          ISBN  CODEN   PubMed ID  \
# 0        NaN  ...                           NaN    NaN         NaN
# 1        184  ...                 9798400714658    NaN         NaN
# 2        NaN  ...                           NaN    NaN         NaN
# 3        NaN  ...                           NaN    NaN  39940766.0
# 4        NaN  ...  9788394593742; 9781628905861    NaN         NaN
#
#   Language of Original Document                   Abbreviated Source Title  \
# 0                       English                                 Algorithms
# 1                       English  GECCO - Proc. Genetic Evol. Comput. Conf.
# 2                       English                                    Cancers
# 3                       English                          Int. J. Mol. Sci.
# 4                       English                        J. Phys. Conf. Ser.
#
#       Document Type Publication Stage  \
# 0           Article             Final
# 1  Conference paper             Final
# 2           Article             Final
# 3           Article             Final
# 4  Conference paper             Final
#
#                                          Open Access  Source  \
# 0                  All Open Access; Gold Open Access  Scopus
# 1                                                NaN  Scopus
# 2  All Open Access; Gold Open Access; Green Accep...  Scopus
# 3  All Open Access; Gold Open Access; Green Accep...  Scopus
# 4                  All Open Access; Gold Open Access  Scopus
#
#                    EID
# 0  2-s2.0-105017372448
# 1  2-s2.0-105013077196
# 2  2-s2.0-105010643815
# 3   2-s2.0-85217742685
# 4   2-s2.0-85219573912
#
# [5 rows x 46 columns]

# %%
#Test e analisi per pulizia dataframe
num_articoli = df.shape[0] #numero aritcoli
null_counts = df.isnull().sum() #Conta valori nulli per colonna
zero_counts = (df == 0).sum() # Conta valori pari a 0 per colonna
print(f"Numero di articoli: {num_articoli}")
#Riepilogo dei valori mancanti
missing_summary = pd.DataFrame({
    "null_values": null_counts,
    "zero_values": zero_counts
})
print(missing_summary)

# Soglia: un terzo dei valori
limite = len(df)/3
cols_to_drop = []# Lista delle colonne da eliminare
for col in df.columns:
    num_null = df[col].isna().sum()
    num_zero = 0
    if pd.api.types.is_numeric_dtype(df[col]):
        num_zero = (df[col] == 0).sum()
    unique_vals = df[col].dropna().unique() #toglie le colonne con un solo valore ripetuto
    if len(unique_vals) <= 1:
        cols_to_drop.append(col)
    # Se la somma di nulli + zeri supera limite, togli la colonna
    if (num_null + num_zero) >= limite:
        cols_to_drop.append(col)
df_clean = df.drop(columns=cols_to_drop)
df_clean.to_csv("nuovo_dataset.csv", index=False)
cols_to_drop
# Out:
# Numero di articoli: 143
#                                null_values  zero_values
# Authors                                  0            0
# Author full names                        0            0
# Author(s) ID                             0            0
# Title                                    0            0
# Year                                     0            0
# Source title                            20            0
# Volume                                  23            0
# Issue                                   77            0
# Art. No.                                95            0
# Page start                              62            0
# Page end                                63            0
# Page count                               0          143
# Cited by                                 0           27
# DOI                                     12            0
# Link                                     0            0
# Affiliations                             0            0
# Authors with affiliations                0            0
# Abstract                                 0            0
# Author Keywords                         36            0
# Index Keywords                          23            0
# Molecular Sequence Numbers             143            0
# Chemicals/CAS                          107            0
# Tradenames                             137            0
# Manufacturers                          140            0
# Funding Details                        100            0
# Funding Texts                           91            0
# References                               3            0
# Correspondence Address                  29            0
# Editors                                113            0
# Publisher                                0            0
# Sponsors                               128            0
# Conference name                        100            0
# Conference date                        100            0
# Conference location                    100            0
# Conference code                        100            0
# ISSN                                    19            0
# ISBN                                    91            0
# CODEN                                  101            0
# PubMed ID                              101            0
# Language of Original Document            0            0
# Abbreviated Source Title                 0            0
# Document Type                            0            0
# Publication Stage                        0            0
# Open Access                             72            0
# Source                                   0            0
# EID                                      0            0
# ['Issue',
#  'Art. No.',
#  'Page start',
#  'Page end',
#  'Page count',
#  'Page count',
#  'Molecular Sequence Numbers',
#  'Molecular Sequence Numbers',
#  'Chemicals/CAS',
#  'Tradenames',
#  'Manufacturers',
#  'Funding Details',
#  'Funding Texts',
#  'Editors',
#  'Sponsors',
#  'Conference name',
#  'Conference date',
#  'Conference location',
#  'Conference code',
#  'ISBN',
#  'CODEN',
#  'PubMed ID',
#  'Language of Original Document',
#  'Open Access',
#  'Source']

# %%
df=pd.read_csv("nuovo_dataset.csv")
num_colonne = df.shape[1]
print("numero di colonne: ", num_colonne)
df.head(46)
# Out:
# numero di colonne:  23
#                                               Authors  \
# 0                            Lancia, G.; Dalpasso, M.
# 1   Da Ros, F.; Di Gaspero, L.; Kletzander, L.; La...
# 2   Bacchetti, E.; de Nardin, A.; Giannarini, G.; ...
# 3   Ozkilinc, O.; Soler, M.A.; Giannozzi, P.; Apar...
# 4               Faletič, S.; Micheli, M.; Pospiec, G.
# 5                Unal, A.; Michelini, M.; Santi, L.G.
# 6                        Della Rossa, M.; Tanwani, A.
# 7   Soler, M.A.; Yakout, R.B.A.; Ozkilinc, O.; Esp...
# 8   Bernardini, A.; Giampiccolo, R.; Bozzo, E.; Fo...
# 9   Kottavalasa, Y.N.; Battaglia, A.; Bevilacqua, ...
# 10  Santi, E.; Dovier, A.; Formisano, A.; Tardivo, F.
# 11           Formisano, A.; Gavazzi, I.; Omodeo, E.G.
# 12           Travasci, S.; Tardivo, F.; Formisano, A.
# 13               Unal, A.; Michelini, M.; Santi, L.G.
# 14                          Minniti, S.; Magaudda, P.
# 15    Ballis, D.; Brodo, L.; Falaschi, M.; Olarte, C.
# 16  Barletta, G.P.; Tandiana, R.; Soler, M.A.; For...
# 17                           Lancia, G.; Dalpasso, M.
# 18         Masullo, F.; Zanolin, F.; Bonet Avalos, J.
# 19             Madni, H.A.; Umer, R.M.; Foresti, G.L.
# 20                              Mari, M.; Snidaro, L.
# 21       Somero, M.; Urli, F.; Snidaro, L.; Liani, A.
# 22  Urli, F.; Somero, M.; Snidaro, L.; Johnson, C....
# 23    Ballis, D.; Brodo, L.; Falaschi, M.; Olarte, C.
# 24  de Nardin, A.; Zottin, S.; Colombi, E.; Piciar...
# 25             Madni, H.A.; Umer, R.M.; Foresti, G.L.
# 26  Fogolari, F.; Borelli, R.; Dovier, A.; Esposit...
# 27                     Ganjali Koli, M.; Fogolari, F.
# 28        Privitera, A.G.; Fontana, F.; Geronazzo, M.
# 29             Madni, H.A.; Umer, R.M.; Foresti, G.L.
# 30  Lettieri, C.; Pauletto, G.; Valiante, G.; Ius,...
# 31  Soler, M.A.; Ozkilinc, O.; Hunashal, Y.; Giann...
# 32  Cirrincione, D.; Antonelli, M.; Aquilanti, G.;...
# 33  Alpuente, M.; Ballis, D.; Escobar, S.; Galán, ...
# 34  Rachevski, A.; Antonelli, M.; Bellutti, P.; Bo...
# 35           Michelini, M.; Faletič, S.; Pospiech, G.
# 36  Affanni, A.; Casarsa, L.; Scagnetto, I.; Trevi...
# 37              Somero, M.; Snidaro, L.; Rogova, G.L.
# 38             Fontana, F.; Bozzo, E.; Bernardini, A.
# 39                                        Dreossi, T.
# 40           Cantone, D.; Omodeo, E.G.; Policriti, A.
# 41  Roitero, K.; Portelli, B.; Serra, G.; Della Me...
# 42  Lettieri, C.; Ius, T.; Verriello, L.; Budai, R...
# 43       Chiapperini, A.; Miculan, M.; Peressotti, M.
# 44  Pilotto, A.; Antonelli, M.; Arfelli, F.; Biasi...
# 45  Beltrami, A.P.; De Martino, M.; Dalla, E.; Mal...
#
#                                     Author full names  \
# 0   Lancia, Giuseppe G. (6701584197); Dalpasso, Ma...
# 1   Da Ros, Francesca (58134137500); Di Gaspero, L...
# 2   Bacchetti, Emiliano (59995162800); de Nardin, ...
# 3   Ozkilinc, Ozge (58138235700); Soler, Miguel A....
# 4   Faletič, Sergej (56595108900); Micheli, Marisa...
# 5   Unal, Aycin (56938060100); Michelini, Marisa (...
# 6   Della Rossa, Matteo (57207046261); Tanwani, An...
# 7   Soler, Miguel A. (8718855800); Yakout, Rayyan ...
# 8   Bernardini, Alberto (57078184800); Giampiccolo...
# 9   Kottavalasa, Yellam Naidu (60098093600); Batta...
# 10  Santi, Enrico (59899260400); Dovier, Agostino ...
# 11  Formisano, Andrea (7003786950); Gavazzi, Isacc...
# 12  Travasci, Stefano (57314700400); Tardivo, Fabi...
# 13  Unal, Aycin (56938060100); Michelini, Marisa (...
# 14  Minniti, Sergio (57193763010); Magaudda, Paolo...
# 15  Ballis, Demis (8672549500); Brodo, Linda (2339...
# 16  Barletta, German Patricio (57199736095); Tandi...
# 17  Lancia, Giuseppe G. (6701584197); Dalpasso, Ma...
# 18  Masullo, Fabrizio (57218686684); Zanolin, Fabi...
# 19  Madni, Hussain Ahmad (57195220347); Umer, Rao ...
# 20  Mari, Marco (59388337700); Snidaro, Lauro (650...
# 21  Somero, Michele (57858103000); Urli, Federico ...
# 22  Urli, Federico (57857396200); Somero, Michele ...
# 23  Ballis, Demis (8672549500); Brodo, Linda (2339...
# 24  de Nardin, Axel (57259162600); Zottin, Silvia ...
# 25  Madni, Hussain Ahmad (57195220347); Umer, Rao ...
# 26  Fogolari, Federico (56233125800); Borelli, Rob...
# 27  Ganjali Koli, Mokhtar (56563030600); Fogolari,...
# 28  Privitera, Alessandro Giuseppe (55329892100); ...
# 29  Madni, Hussain Ahmad (57195220347); Umer, Rao ...
# 30  Lettieri, Christian (36892689100); Pauletto, G...
# 31  Soler, Miguel A. (8718855800); Ozkilinc, Ozge ...
# 32  Cirrincione, Daniela (57201132189); Antonelli,...
# 33  Alpuente, María (6701736591); Ballis, Demis (8...
# 34  Rachevski, Alexandre (14833311600); Antonelli,...
# 35  Michelini, Marisa (23016123800); Faletič, Serg...
# 36  Affanni, A. (55957389200); Casarsa, Luca (2348...
# 37  Somero, Michele (57858103000); Snidaro, Lauro ...
# 38  Fontana, Federico (55970349500); Bozzo, Enrico...
# 39                     Dreossi, Talissa (59376711000)
# 40  Cantone, Domenico (55892604800); Omodeo, Eugen...
# 41  Roitero, Kevin (57191042663); Portelli, Beatri...
# 42  Lettieri, Christian (36892689100); Ius, Tamara...
# 43  Chiapperini, Alessio (57218189772); Miculan, M...
# 44  Pilotto, A. (57199998056); Antonelli, Matias (...
# 45  Beltrami, A. P. (15070243200); De Martino, Mar...
#
#                                          Author(s) ID  \
# 0                              6701584197; 6603897248
# 1   58134137500; 6505944235; 57194560339; 57188717...
# 2   59995162800; 57259162600; 55883317500; 2448058...
# 3   58138235700; 8718855800; 7004488307; 572046647...
# 4               56595108900; 59664609000; 59665606800
# 5               56938060100; 23016123800; 35227961200
# 6                            57207046261; 26422519500
# 7   8718855800; 59506327000; 58138235700; 72023173...
# 8   57078184800; 57224829981; 8964011500; 55970349500
# 9   60098093600; 60097745700; 59798921000; 2348601...
# 10   59899260400; 6603827082; 7003786950; 56131143900
# 11                7003786950; 60032085900; 6601981618
# 12               57314700400; 56131143900; 7003786950
# 13              56938060100; 23016123800; 35227961200
# 14                           57193763010; 14123752500
# 15    8672549500; 23395914900; 7004184628; 8704203900
# 16  57199736095; 57226809183; 8718855800; 28067666...
# 17                             6701584197; 6603897248
# 18               57218686684; 6603355707; 57193912191
# 19               57195220347; 57211291072; 7006427233
# 20                            59388337700; 6507499895
# 21  57858103000; 57857396200; 6507499895; 57549486700
# 22  57857396200; 57858103000; 6507499895; 59388221...
# 23    8672549500; 23395914900; 7004184628; 8704203900
# 24  57259162600; 57959422500; 36462381800; 9039137...
# 25               57195220347; 57211291072; 7006427233
# 26   56233125800; 58634818300; 6603827082; 7202317328
# 27                           56563030600; 56233125800
# 28              55329892100; 55970349500; 36720522500
# 29               57195220347; 57211291072; 7006427233
# 30  36892689100; 6602640764; 36892239600; 15725154...
# 31  8718855800; 58138235700; 57204035340; 70044883...
# 32  57201132189; 56341882700; 55913711400; 7003628...
# 33  6701736591; 8672549500; 6701593474; 5799183580...
# 34  14833311600; 56341882700; 7003628332; 56243550...
# 35              23016123800; 56595108900; 36662694200
# 36  55957389200; 23487856800; 56242036400; 2223561...
# 37                57858103000; 6507499895; 6602632486
# 38               55970349500; 8964011500; 57078184800
# 39                                        59376711000
# 40                55892604800; 6601981618; 6701331312
# 41  57191042663; 57219796263; 10140344600; 7003376...
# 42  36892689100; 15725154500; 6506798519; 66026770...
# 43               57218189772; 6602346936; 56208605300
# 44  57199998056; 56341882700; 7003677341; 57204892...
# 45  15070243200; 57221721546; 6602989136; 56587718...
#
#                                                 Title  Year  \
# 0   Speeding Up Floyd–Warshall’s Algorithm to Comp...  2025
# 1   Dynamic Temperature Control of Simulated Annea...  2025
# 2   A Deep Learning Model Integrating Clinical and...  2025
# 3   The Single-Parameter Bragg–Williams Model for ...  2025
# 4   Teaching and learning quantum entanglement: a ...  2025
# 5   Teachers' Perspectives and Practices on Teachi...  2025
# 6   Converse Lyapunov results for stability of swi...  2025
# 7   Bluues_cplx: Electrostatics at Protein–Protein...  2025
# 8   Wave Digital Extended Fixed-Point Solvers for ...  2025
# 9   Fusion-Based LSTM-GRU-Attention Model for Time...  2025
# 10          GPU Accelerated Compact-Table Propagation  2025
# 11  Diophantine Modeling of Provability in Algebra...  2025
# 12  GPU-Accelerated Propagation for the Stable Mar...  2025
# 13  A Multi-phase Research on Developing Proposals...  2025
# 14  The ‘obligatory passage point’ in knowledge co...  2025
# 15  ccReact: a rewriting framework for the formal ...  2024
# 16  Locuaz: an in silico platform for protein bind...  2024
# 17  Algorithmic strategies for a fast exploration ...  2024
# 18  Folding Domain Functions (FDF): A Random Varia...  2024
# 19  Robust Federated Learning for Heterogeneous Mo...  2024
# 20  Ensemble of KalmanNets for Maneuvering Target ...  2024
# 21  Defect detection MultiHeadAttention Fusion mod...  2024
# 22  FeU-Net: Overcomplete representations with lar...  2024
# 23  Process Calculi and Rewriting Techniques for A...  2024
# 24  Is ImageNet Always the Best Option? An Overvie...  2024
# 25  Federated Learning for Data and Model Heteroge...  2024
# 26  The kth nearest neighbor method for estimation...  2024
# 27  Exploring the role of cyclodextrins as a chole...  2023
# 28  On the Effect of User Tracking on Perceived So...  2023
# 29  Swarm-FHE: Fully Homomorphic Encryption-based ...  2023
# 30  Fast or Slow? A Comparison Between Two Transcr...  2023
# 31  Molecular electrostatics and pKa shifts calcul...  2023
# 32  A new collimated multichannel modular detectio...  2023
# 33  Safety enforcement via programmable strategies...  2023
# 34  eXTP Large Area Detector: Qualification proced...  2023
# 35  Approaches and Teaching Resources for Teacher ...  2023
# 36  Acquisition and integration of differential pr...  2023
# 37  Deep Classifiers Evidential Fusion with Reliab...  2023
# 38  Extended Fixed-Point Methods for the Computati...  2023
# 39    Exploring ILASP Through Logic Puzzles Modelling  2023
# 40   Continued Hereditarily Finite Set-Approximations  2023
# 41  Detection of Wastewater Pollution Through Natu...  2023
# 42  Risk Factors for Intraoperative Seizures in Gl...  2023
# 43  Computing (optimal) embeddings of directed big...  2022
# 44  Modeling Approaches for Gain, Noise and Time R...  2022
# 45  Combining Deep Phenotyping of Serum Proteomics...  2022
#
#                                          Source title      Volume  Cited by  \
# 0                                          Algorithms          18         0
# 1                                                 NaN         NaN         0
# 2                                             Cancers          17         0
# 3         International Journal of Molecular Sciences          26         0
# 4               Journal of Physics: Conference Series        2950         0
# 5               Journal of Physics: Conference Series        2950         0
# 6   ESAIM - Control, Optimisation and Calculus of ...          31         0
# 7                                           Molecules          30         1
# 8           IEEE Transactions on Circuits and Systems          72         2
# 9                                                 NaN         NaN         1
# 10           Theory and Practice of Logic Programming         NaN         0
# 11                          CEUR Workshop Proceedings        4003         0
# 12                          CEUR Workshop Proceedings        4003         1
# 13                    Challenges in Physics Education   Part F643         0
# 14                                 Science as Culture          34         4
# 15  International Journal on Software Tools for Te...          26         0
# 16                                     Bioinformatics          40         1
# 17                              Journal of Heuristics          30         1
# 18  Communications in Nonlinear Science and Numeri...         133         0
# 19            International Journal of Neural Systems          34         5
# 20                                                NaN         NaN         2
# 21                                                NaN         NaN         0
# 22                                                NaN         NaN         1
# 23                  Lecture Notes in Computer Science  14971 LNBI         2
# 24                  Lecture Notes in Computer Science       14366         3
# 25                  Lecture Notes in Computer Science       14366         8
# 26  Wiley Interdisciplinary Reviews: Computational...          14         4
# 27                                 Scientific Reports          13        19
# 28                                                NaN         NaN         4
# 29            International Journal of Neural Systems          33        16
# 30                Journal of Clinical Neurophysiology          40         4
# 31                    Computer Physics Communications         287         5
# 32  Nuclear Instruments and Methods in Physics Res...        1049         4
# 33  Journal of Logical and Algebraic Methods in Pr...         132         1
# 34  Nuclear Instruments and Methods in Physics Res...        1046         4
# 35                    Challenges in Physics Education  Part F1979         1
# 36                                         Acta IMEKO          12         4
# 37                                                NaN         NaN         1
# 38                     IEEE Signal Processing Letters          30         1
# 39                          CEUR Workshop Proceedings        3428         3
# 40                          CEUR Workshop Proceedings        3428         0
# 41                                        IEEE Access          11         6
# 42                Journal of Clinical Neurophysiology          40        10
# 43                    Science of Computer Programming         221         1
# 44                               Frontiers in Physics          10         7
# 45        International Journal of Molecular Sciences          23        13
#
#                                    DOI  \
# 0                    10.3390/a18090560
# 1              10.1145/3712256.3726390
# 2              10.3390/cancers17132257
# 3                 10.3390/ijms26030997
# 4      10.1088/1742-6596/2950/1/012025
# 5      10.1088/1742-6596/2950/1/012008
# 6                 10.1051/cocv/2025006
# 7            10.3390/molecules30010159
# 8            10.1109/TCSI.2024.3488508
# 9   10.23919/FUSION65864.2025.11123885
# 10           10.1017/S1471068425100197
# 11                                 NaN
# 12                                 NaN
# 13        10.1007/978-3-031-86609-8_16
# 14       10.1080/09505431.2024.2317236
# 15          10.1007/s10009-024-00772-z
# 16      10.1093/bioinformatics/btae492
# 17          10.1007/s10732-023-09523-w
# 18         10.1016/j.cnsns.2024.107948
# 19           10.1142/S0129065724500199
# 20  10.23919/FUSION59988.2024.10706253
# 21  10.23919/FUSION59988.2024.10706339
# 22  10.23919/FUSION59988.2024.10706398
# 23         10.1007/978-3-031-71671-3_1
# 24        10.1007/978-3-031-51026-7_41
# 25        10.1007/978-3-031-51026-7_15
# 26                   10.1002/wcms.1691
# 27          10.1038/s41598-023-49217-8
# 28             10.1145/3605390.3605422
# 29           10.1142/S0129065723500338
# 30        10.1097/WNP.0000000000000902
# 31           10.1016/j.cpc.2023.108716
# 32          10.1016/j.nima.2023.168118
# 33         10.1016/j.jlamp.2023.100849
# 34          10.1016/j.nima.2022.167750
# 35         10.1007/978-3-031-44312-1_6
# 36       10.21014/actaimeko.v12i4.1555
# 37  10.23919/FUSION52260.2023.10224105
# 38            10.1109/LSP.2023.3294132
# 39                                 NaN
# 40                                 NaN
# 41         10.1109/ACCESS.2023.3277535
# 42        10.1097/WNP.0000000000000854
# 43         10.1016/j.scico.2022.102842
# 44            10.3389/fphy.2022.944206
# 45                10.3390/ijms23169161
#
#                                                  Link  ...  \
# 0   https://www.scopus.com/inward/record.uri?eid=2...  ...
# 1   https://www.scopus.com/inward/record.uri?eid=2...  ...
# 2   https://www.scopus.com/inward/record.uri?eid=2...  ...
# 3   https://www.scopus.com/inward/record.uri?eid=2...  ...
# 4   https://www.scopus.com/inward/record.uri?eid=2...  ...
# 5   https://www.scopus.com/inward/record.uri?eid=2...  ...
# 6   https://www.scopus.com/inward/record.uri?eid=2...  ...
# 7   https://www.scopus.com/inward/record.uri?eid=2...  ...
# 8   https://www.scopus.com/inward/record.uri?eid=2...  ...
# 9   https://www.scopus.com/inward/record.uri?eid=2...  ...
# 10  https://www.scopus.com/inward/record.uri?eid=2...  ...
# 11  https://www.scopus.com/inward/record.uri?eid=2...  ...
# 12  https://www.scopus.com/inward/record.uri?eid=2...  ...
# 13  https://www.scopus.com/inward/record.uri?eid=2...  ...
# 14  https://www.scopus.com/inward/record.uri?eid=2...  ...
# 15  https://www.scopus.com/inward/record.uri?eid=2...  ...
# 16  https://www.scopus.com/inward/record.uri?eid=2...  ...
# 17  https://www.scopus.com/inward/record.uri?eid=2...  ...
# 18  https://www.scopus.com/inward/record.uri?eid=2...  ...
# 19  https://www.scopus.com/inward/record.uri?eid=2...  ...
# 20  https://www.scopus.com/inward/record.uri?eid=2...  ...
# 21  https://www.scopus.com/inward/record.uri?eid=2...  ...
# 22  https://www.scopus.com/inward/record.uri?eid=2...  ...
# 23  https://www.scopus.com/inward/record.uri?eid=2...  ...
# 24  https://www.scopus.com/inward/record.uri?eid=2...  ...
# 25  https://www.scopus.com/inward/record.uri?eid=2...  ...
# 26  https://www.scopus.com/inward/record.uri?eid=2...  ...
# 27  https://www.scopus.com/inward/record.uri?eid=2...  ...
# 28  https://www.scopus.com/inward/record.uri?eid=2...  ...
# 29  https://www.scopus.com/inward/record.uri?eid=2...  ...
# 30  https://www.scopus.com/inward/record.uri?eid=2...  ...
# 31  https://www.scopus.com/inward/record.uri?eid=2...  ...
# 32  https://www.scopus.com/inward/record.uri?eid=2...  ...
# 33  https://www.scopus.com/inward/record.uri?eid=2...  ...
# 34  https://www.scopus.com/inward/record.uri?eid=2...  ...
# 35  https://www.scopus.com/inward/record.uri?eid=2...  ...
# 36  https://www.scopus.com/inward/record.uri?eid=2...  ...
# 37  https://www.scopus.com/inward/record.uri?eid=2...  ...
# 38  https://www.scopus.com/inward/record.uri?eid=2...  ...
# 39  https://www.scopus.com/inward/record.uri?eid=2...  ...
# 40  https://www.scopus.com/inward/record.uri?eid=2...  ...
# 41  https://www.scopus.com/inward/record.uri?eid=2...  ...
# 42  https://www.scopus.com/inward/record.uri?eid=2...  ...
# 43  https://www.scopus.com/inward/record.uri?eid=2...  ...
# 44  https://www.scopus.com/inward/record.uri?eid=2...  ...
# 45  https://www.scopus.com/inward/record.uri?eid=2...  ...
#
#                                       Author Keywords  \
# 0   all-pairs shortest paths; FastSet data structu...
# 1   combinatorial optimization; empirical analysis...
# 2   artificial intelligence; biopsy; magnetic reso...
# 3   binary mixtures; Bragg–Williams; eutectic solv...
# 4                                                 NaN
# 5                                                 NaN
# 6   Average dwell-time; Converse results; Multiple...
# 7   bluues; complex; electrostatics; free energy; ...
# 8   circuit simulation; extended fixed-point solve...
# 9   Fouling Factor; Fusion Model; Neural Networks;...
# 10  constraint logic programming; GPU parallelism;...
# 11    Algebraic logic; Class theory; Diophantine sets
# 12  Constraint Programming; Global Constraint; GPU...
# 13  Focus group interview; Properties of matter; T...
# 14  Actor Network Theory; Knowledge co-production;...
# 15  Maude; Model checking; Reaction systems; Rewri...
# 16                                                NaN
# 17    4-OPT; Local search; Traveling salesman problem
# 18  Applications; Density function; Distribution f...
# 19  collaborative machine learning; data and model...
# 20  Kalman Filter; Recurrent Neural Network; Targe...
# 21  Attention; Defect Detection; Fusion; Illuminat...
# 22  Edge detection; Features fusion; Large kernels...
# 23  Maude; model checking; reaction systems; rewri...
# 24  Document Layout Analysis; Fine Tuning Approach...
# 25  Federated Learning; Heterogeneous Data; Hetero...
# 26  conformational entropy; entropy; kth nearest n...
# 27                                                NaN
# 28  Augumented reality; Earables.; Sonic interacti...
# 29  federated learning; fully homomorphic encrypti...
# 30  "Fast-charge"; "Slow-charge"; Intraoperative m...
# 31  Continuum models; Electrostatics; Generalized ...
# 32  Collimation; Detection system; Silicon Drift D...
# 33  Formal methods; Maude; Program safety; Rewriti...
# 34        Silicon drift detectors; X-ray spectroscopy
# 35                                                NaN
# 36  GPS data; sail differential pressure; Target d...
# 37  Classifier Fusion; Decision fusion; Deep Learn...
# 38  delay-free loop; Fixed point (FP) methods; new...
# 39  ASP; ILASP; learning constraints; logic progra...
# 40  Ackermann codes; continued fractions; heredita...
# 41  causal models; language models; low-cost senso...
# 42  Awake craniotomy; Cortical stimulation; Epilep...
# 43  Bigraphs; Graph rewriting systems; Integer lin...
# 44  avalanche photodiodes; modeling; Monte Carlo m...
# 45  cardiometabolic; COVID-19; inflammation; neuro...
#
#                                        Index Keywords  \
# 0   Computational complexity; Graph algorithms; Al...
# 1   Application programs; Artificial intelligence;...
# 2   alpha adrenergic receptor blocking agent; pros...
# 3   deep eutectic solvent; solvent; Article; Bragg...
# 4   Quantum optics; Empirical research; Fundamenta...
# 5   Elementary and middle schools; Method and tech...
# 6   Lyapunov functions; Lyapunov methods; Nonlinea...
# 7   ligand; protein; protein binding; chemical phe...
# 8   Bandpass filters; Digital filters; Inverse pro...
# 9   Data fusion; Forecasting; Fouling; Industrial ...
# 10  Computation theory; Computer circuits; Compute...
# 11  Formal logic; Polynomials; Theorem proving; Al...
# 12  Computer systems programming; Constraint handl...
# 13                                                NaN
# 14                                                NaN
# 15  Context sensitive languages; Formal verificati...
# 16  protein; protein binding; bioinformatics; chem...
# 17  Dynamic programming; Local search (optimizatio...
# 18  Distribution functions; Numerical methods; Ord...
# 19  Distillation; Machine learning; Sensitive data...
# 20  Kalman filters; Maneuverability; Neural networ...
# 21  Image acquisition; Image fusion; Attention; Co...
# 22  Deep learning; Edge detection; Medical imaging...
# 23  Context sensitive languages; Model checking; M...
# 24  Image analysis; Image enhancement; Large datas...
# 25  Distillation; Learning systems; Medical imagin...
# 26  Bioinformatics; Computational chemistry; Confo...
# 27  beta cyclodextrin derivative; cholesterol; cyc...
# 28  Acoustic generators; Audio acoustics; Signal p...
# 29  Blockchain; Cryptography; Generative adversari...
# 30  neuromuscular blocking agent; propofol; remife...
# 31  Atoms; Bioinformatics; Biological systems; Bol...
# 32  Light sources; Silicon; Silicon detectors; Syn...
# 33  Computer circuits; Formal methods; Logic compu...
# 34  Silicon; Silicon detectors; X ray detectors; C...
# 35                                                NaN
# 36                                                NaN
# 37  Convolutional neural networks; Decision theory...
# 38  Bandpass filters; Computational efficiency; Co...
# 39  Computer circuits; Knowledge based systems; Le...
# 40  Set theory; Ackermann code; Arbitrary precisio...
# 41  Classification (of information); Costs; Deep l...
# 42  adult; aged; alpha rhythm; awake craniotomy; b...
# 43  Biological systems; Computation theory; Constr...
# 44  Aluminum gallium arsenide; Avalanche photodiod...
# 45  alpha 2 microglobulin receptor associated prot...
#
#                                            References  \
# 0   Floyd, Robert W., Algorithm 97: Shortest path,...
# 1   Adriaensen, Steven, Fair-share ILS: A simple s...
# 2   Cornford, Philip A., EAU-EANM-ESTRO-ESUR-ISUP-...
# 3   Abbott, Andrew P., Deep Eutectic Solvents form...
# 4   J Phys Conf Ser, (2021); Qtedu Consortium 2021...
# 5   Hadenfeldt, Jan Christoph, Framing students’ p...
# 6   Morse, A. Stephen, Supervisory control of fami...
# 7   Nooren, Irene M.A., Diversity of protein-prote...
# 8   Z̈olzer, Udo, DAFX: Digital Audio Effects: Sec...
# 9   Inverse Heat Conduction and Heat Exchangers, (...
# 10  Assi, Maram, A Survey of the Knapsack Problem,...
# 11  Introduction to Metamathematics, (1952); Annal...
# 12  Stable Marriage Problem Structure and Algorith...
# 13  Sci Child, (2017); Acta Didactica Napocensia, ...
# 14  Bell, Simon, The state of automated amateur we...
# 15  Alpuente, María, A rewriting logic approach to...
# 16  Abraham, Mark James, Gromacs: High performance...
# 17  Local Search in Combinatorial Optimization, (1...
# 18  Random Dynamical Systems, (1998); Random Diffe...
# 19  Communication Efficient Learning of Deep Netwo...
# 20  A New Approach to Linear Filtering and Predict...
# 21  Chazhoor, Anthony Ashwin Peter, A Review and B...
# 22  Bernal, Jorge, WM-DOVA maps for accurate polyp...
# 23  Alpuente, María, $${\textsf {ACUOS}}^\mathbf {...
# 24  Andrist, Patrick, Toward a definition of parat...
# 25  Icml, (2017); Arxiv, (2020); Fang, Xiuwen, Rob...
# 26  Physical Chemistry, (1990); Goldenzweig, Adi, ...
# 27  MacH, François, 2019 ESC/EAS guidelines for th...
# 28  Agus, Natalie, Minimally simple binaural room ...
# 29  Tian, Yingjie, Recent advances on loss functio...
# 30  Legatt, Alan D., ACNS Guideline: Transcranial ...
# 31  Harvey, Stephen C., Treatment of electrostatic...
# 32  Rachevski, Alexandre, The XAFS fluorescence de...
# 33  Rubio, Rubén, Strategies, model checking and b...
# 34  Zhang, Shuangnan, The enhanced X-ray Timing an...
# 35  Training Pre Service and in Service Secondary ...
# 36  Velocity Preditcion Program; Viola, Ignazio Ma...
# 37  Proceedings of the First Conference on Multiso...
# 38  Välimäki, Vesa, Virtual Analog Effects, pp. 47...
# 39  Machine Learning, (2009); Ding, Weiping, Expla...
# 40  Policriti, Alberto, Encodings of sets and hype...
# 41  Lee, Lester T., Long-Term Monitoring of Water ...
# 42  Kim, Stephan S., Awake craniotomy for brain tu...
# 43  Archibald, Blair, Practical bigraphs via subgr...
# 44  Renker, Dieter, Geiger-mode avalanche photodio...
# 45  Rodriguez-Morales, Alfonso J., Clinical, labor...
#
#                                Correspondence Address  \
# 0   G. Lancia; Department of Mathematics, Computer...
# 1                                                 NaN
# 2   G. Giannarini; Urology Unit, University Hospit...
# 3   F. Fogolari; Dipartimento di Scienze Matematic...
# 4   S. Faletič; University of Ljubljana, Faculty o...
# 5   A. Ünal; Research Unit in Physics Education, D...
# 6   M. Della Rossa; Dipartimento di Scienze Matema...
# 7   F. Fogolari; Dipartimento di Scienze Matematic...
# 8   A. Bernardini; Politecnico di Milano, Dipartim...
# 9                                                 NaN
# 10                                                NaN
# 11  A. Formisano; DMIF, Dept. of Mathematics, Comp...
# 12  A. Formisano; University of Udine, DMIF, Italy...
# 13  A. Ünal; Research Unit in Physics Education, D...
# 14  S. Minniti; Department of Mathematics, Compute...
# 15  D. Ballis; DMIF, University of Udine, Udine, I...
# 16  G.P. Barletta; CONCEPT, Istituto Italiano di T...
# 17  G. Lancia; DMIF, University of Udine, Udine, V...
# 18  F. Zanolin; Department of Mathematics, Compute...
# 19  G.L. Foresti; Department of Mathematics, Compu...
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23  C. Olarte; LIPN, CNRS UMR 7030, Université Sor...
# 24  A. De Nardin; Department of Mathematics, Infor...
# 25  H.A. Madni; Department of Mathematics, Compute...
# 26  F. Fogolari; Dipartimento di Scienze Matematic...
# 27  M. Ganjali Koli; Department of Chemistry, Univ...
# 28                                                NaN
# 29  G.L. Foresti; Department of Mathematics, Compu...
# 30  C. Lettieri; Neurology and Clinical Neurophysi...
# 31  F. Fogolari; Dipartimento di Scienze Matematic...
# 32  D. Cirrincione; INFN Trieste, Trieste, Padrici...
# 33  D. Ballis; DMIF, University of Udine, Udine, V...
# 34  A. Rachevski; INFN Trieste, Trieste, Padrician...
# 35  S. Faletič; Faculty of Mathematics and Physics...
# 36  A. Affanni; Polytechnic Department of Engineer...
# 37                                                NaN
# 38  F. Fontana; University of Udine, Department of...
# 39  T. Dreossi; University of Udine, DMIF, Udine, ...
# 40  D. Cantone; University of Catania, DMI, Catani...
# 41  K. Roitero; University of Udine, Informatiche ...
# 42  C. Lettieri; Neurology and Clinical Neurophysi...
# 43  M. Peressotti; IMADA, University of Southern D...
# 44  P. Palestri; DPIA, University of Udine, Udine,...
# 45  C. Tascini; Department of Medicine (DAME), Uni...
#
#                                             Publisher                ISSN  \
# 0   Multidisciplinary Digital Publishing Institute...            19994893
# 1            Association for Computing Machinery, Inc                 NaN
# 2   Multidisciplinary Digital Publishing Institute...            20726694
# 3   Multidisciplinary Digital Publishing Institute...  14220067; 16616596
# 4                                Institute of Physics  17426588; 17426596
# 5                                Institute of Physics  17426588; 17426596
# 6                                        EDP Sciences  12928119; 12623377
# 7   Multidisciplinary Digital Publishing Institute...            14203049
# 8   Institute of Electrical and Electronics Engine...            15498328
# 9   Institute of Electrical and Electronics Engine...                 NaN
# 10                         Cambridge University Press  14710684; 14753081
# 11                                            CEUR-WS            16130073
# 12                                            CEUR-WS            16130073
# 13                                    Springer Nature  26628422; 26628430
# 14                                          Routledge            09505431
# 15  Springer Science and Business Media Deutschlan...  14332779; 14332787
# 16                            Oxford University Press  13674803; 13674811
# 17                                           Springer  13811231; 15729397
# 18                                      Elsevier B.V.            10075704
# 19                                   World Scientific  01290657; 17936462
# 20  Institute of Electrical and Electronics Engine...                 NaN
# 21  Institute of Electrical and Electronics Engine...                 NaN
# 22  Institute of Electrical and Electronics Engine...                 NaN
# 23  Springer Science and Business Media Deutschlan...  03029743; 16113349
# 24  Springer Science and Business Media Deutschlan...  03029743; 16113349
# 25  Springer Science and Business Media Deutschlan...  03029743; 16113349
# 26                            John Wiley and Sons Inc  17590876; 17590884
# 27                                    Nature Research            20452322
# 28                Association for Computing Machinery                 NaN
# 29                                   World Scientific  01290657; 17936462
# 30                    Lippincott Williams and Wilkins  07360258; 15371603
# 31                                      Elsevier B.V.            00104655
# 32                                      Elsevier B.V.            01689002
# 33                                      Elsevier Inc.  23522208; 23522216
# 34                                      Elsevier B.V.            01689002
# 35                                    Springer Nature  26628422; 26628430
# 36    International Measurement Confederation (IMEKO)  0237028X; 2221870X
# 37  Institute of Electrical and Electronics Engine...                 NaN
# 38  Institute of Electrical and Electronics Engine...  10709908; 15582361
# 39                                            CEUR-WS            16130073
# 40                                            CEUR-WS            16130073
# 41  Institute of Electrical and Electronics Engine...            21693536
# 42                    Lippincott Williams and Wilkins  07360258; 15371603
# 43                                      Elsevier B.V.            01676423
# 44                                 Frontiers Media SA            2296424X
# 45                                               MDPI  14220067; 16616596
#
#                      Abbreviated Source Title     Document Type  \
# 0                                  Algorithms           Article
# 1   GECCO - Proc. Genetic Evol. Comput. Conf.  Conference paper
# 2                                     Cancers           Article
# 3                           Int. J. Mol. Sci.           Article
# 4                         J. Phys. Conf. Ser.  Conference paper
# 5                         J. Phys. Conf. Ser.  Conference paper
# 6             Control Optimisation Calc. Var.           Article
# 7                                   Molecules           Article
# 8      IEEE Trans. Circuits Syst. Regul. Pap.           Article
# 9        Proc. Int. Conf. Inf. Fusion, FUSION  Conference paper
# 10              Theory Pract. Logic Programm.           Article
# 11                        CEUR Workshop Proc.  Conference paper
# 12                        CEUR Workshop Proc.  Conference paper
# 13                         Chall. Phys. Educ.      Book chapter
# 14                                 Sci. Cult.           Article
# 15       Int. J. Softw. Tools Technol. Trans.           Article
# 16                             Bioinformatics           Article
# 17                               J Heuristics           Article
# 18         Comm. Nonlinear Sci. Numer. Simul.           Article
# 19                       Int. J. Neural Syst.           Article
# 20            FUSION - Int. Conf. Inf. Fusion  Conference paper
# 21            FUSION - Int. Conf. Inf. Fusion  Conference paper
# 22            FUSION - Int. Conf. Inf. Fusion  Conference paper
# 23                   Lect. Notes Comput. Sci.  Conference paper
# 24                   Lect. Notes Comput. Sci.  Conference paper
# 25                   Lect. Notes Comput. Sci.  Conference paper
# 26  Wiley Interdiscip. Rev. Comput. Mol. Sci.            Review
# 27                                  Sci. Rep.           Article
# 28                  ACM Int. Conf. Proc. Ser.  Conference paper
# 29                       Int. J. Neural Syst.           Article
# 30                     J. Clin. Neurophysiol.           Article
# 31                         Comput Phys Commun           Article
# 32       Nucl Instrum Methods Phys Res Sect A           Article
# 33      J. Logica. Algebraic Methods Program.           Article
# 34       Nucl Instrum Methods Phys Res Sect A           Article
# 35                         Chall. Phys. Educ.      Book chapter
# 36                                 Acta IMEKO           Article
# 37             Int. Conf. Inf. Fusion, FUSION  Conference paper
# 38                   IEEE Signal Process Lett           Article
# 39                        CEUR Workshop Proc.  Conference paper
# 40                        CEUR Workshop Proc.  Conference paper
# 41                                IEEE Access           Article
# 42                     J. Clin. Neurophysiol.  Conference paper
# 43                         Sci Comput Program           Article
# 44                               Front. Phys.           Article
# 45                          Int. J. Mol. Sci.           Article
#
#    Publication Stage                  EID
# 0              Final  2-s2.0-105017372448
# 1              Final  2-s2.0-105013077196
# 2              Final  2-s2.0-105010643815
# 3              Final   2-s2.0-85217742685
# 4              Final   2-s2.0-85219573912
# 5              Final   2-s2.0-85219548280
# 6              Final   2-s2.0-85218944729
# 7              Final   2-s2.0-85214473493
# 8              Final   2-s2.0-85208596332
# 9              Final  2-s2.0-105015864943
# 10               aip  2-s2.0-105014539999
# 11             Final  2-s2.0-105012765071
# 12             Final  2-s2.0-105012747528
# 13             Final  2-s2.0-105011706168
# 14             Final  2-s2.0-105001874051
# 15             Final   2-s2.0-85213707745
# 16             Final   2-s2.0-85201423747
# 17             Final   2-s2.0-85180262864
# 18             Final   2-s2.0-85188535627
# 19             Final   2-s2.0-85186633262
# 20             Final   2-s2.0-85207694903
# 21             Final   2-s2.0-85207693451
# 22             Final   2-s2.0-85207691043
# 23             Final   2-s2.0-85205381867
# 24             Final   2-s2.0-85184122509
# 25             Final   2-s2.0-85184083430
# 26             Final   2-s2.0-85173457958
# 27             Final   2-s2.0-85178923560
# 28             Final   2-s2.0-85173659160
# 29             Final   2-s2.0-85163185989
# 30             Final   2-s2.0-85135171388
# 31             Final   2-s2.0-85149895484
# 32             Final   2-s2.0-85148686788
# 33             Final   2-s2.0-85147098729
# 34             Final   2-s2.0-85142420818
# 35             Final   2-s2.0-85180640036
# 36             Final   2-s2.0-85178134940
# 37             Final   2-s2.0-85171563686
# 38             Final   2-s2.0-85164750644
# 39             Final   2-s2.0-85164621056
# 40             Final   2-s2.0-85164589131
# 41             Final   2-s2.0-85160215938
# 42             Final   2-s2.0-85140632311
# 43             Final   2-s2.0-85135478850
# 44             Final   2-s2.0-85138171161
# 45             Final   2-s2.0-85137728062
#
# [46 rows x 23 columns]

# %% [markdown]
# ## Creazione del primo grafo
# Creazione del grafo per anno che mostra la relazione delle collaborazioni tra autori delle varie pubblicazioni.

# %%
df["authors_list"] = df["Authors"].str.split(",")
df["authors_list"] = df["authors_list"].apply(
    lambda x: [a.strip() for a in x] if isinstance(x, list) else x
)

# assicura che Year sia numerico
df["Year"] = pd.to_numeric(df["Year"], errors="coerce")
grafi_per_anno = {}
for anno, df_anno in df.groupby("Year"):
    G = nx.Graph()
    for authors in df_anno["authors_list"].dropna():
        for a1, a2 in itertools.combinations(authors, 2):
            if G.has_edge(a1, a2):
                G[a1][a2]["weight"] += 1
            else:
                G.add_edge(a1, a2, weight=1)
    grafi_per_anno[anno] = G

# %%
## sistemare nomi pallini e archi
pos = nx.circular_layout(
    nx.compose_all(grafi_per_anno.values())
)
def plot_graph_plotly(G):
    edge_x, edge_y = [], []

    for u, v in G.edges():
        x0, y0 = pos[u]
        x1, y1 = pos[v]
        edge_x += [x0, x1, None]
        edge_y += [y0, y1, None]

    edge_trace = go.Scatter(
        x=edge_x,
        y=edge_y,
        mode="lines",
        line=dict(width=1, color="gray"),
        hoverinfo="none"
    )

    node_x, node_y, hover_text = [], [], []

    for node in G.nodes():
        x, y = pos[node]
        node_x.append(x)
        node_y.append(y)
        hover_text.append(
            f"{node}<br>Collaborazioni: {G.degree(node)}"
        )

    node_trace = go.Scatter(
        x=node_x,
        y=node_y,
        mode="markers",
        hoverinfo="text",
        text=hover_text,
        marker=dict(
            size=8,
            color="royalblue",
            line=dict(width=0.5, color="black")
        )
    )

    return edge_trace, node_trace
frames = []

for anno in sorted(grafi_per_anno.keys()):
    edge, node = plot_graph_plotly(grafi_per_anno[anno])
    frames.append(
        go.Frame(
            data=[edge, node],
            name=str(anno)
        )
    )

fig = go.Figure(
    data=frames[0].data,
    frames=frames,
    layout=go.Layout(
        title="Collaborazioni tra autori nel tempo",
        paper_bgcolor="white",
        plot_bgcolor="white",

        xaxis=dict(
            showgrid=False,
            zeroline=False,
            visible=False
        ),
        yaxis=dict(
            showgrid=False,
            zeroline=False,
            visible=False
        ),

        updatemenus=[{
            "type": "buttons",
            "buttons": [{
                "label": "Play",
                "method": "animate",
                "args": [
                    None,
                    {
                        "frame": {"duration": 2000, "redraw": True}, 
                        "transition": {"duration": 500},
                        "fromcurrent": True
                    }
                ]
            }]
        }],

        sliders=[{
            "steps": [
                {
                    "method": "animate",
                    "args": [[f.name]],
                    "label": f.name
                }
                for f in frames
            ]
        }]
    )
)

fig.show()

# %%
#Calcolo del layout su TUTTI i nodi (coerenza tra anni)
G_totale = nx.compose_all(grafi_per_anno.values())
pos = nx.spring_layout(G_totale, seed=42)  # layout “a molla”, riproducibile
def plot_graph_plotly(G, pos):
    edge_x, edge_y = [], []
    for u, v in G.edges():
        x0, y0 = pos[u]
        x1, y1 = pos[v]
        edge_x += [x0, x1, None]
        edge_y += [y0, y1, None]
    edge_trace = go.Scatter(
        x=edge_x, y=edge_y,
        mode="lines",
        line=dict(width=1, color="gray"),
        hoverinfo="none"
    )
    node_x, node_y, hover_text = [], [], []
    sizes = []
    for node in G.nodes():
        x, y = pos[node]
        node_x.append(x)
        node_y.append(y)
        hover_text.append(f"{node}<br>Collaborazioni: {G.degree(node)}")
        sizes.append(5 + G.degree(node) * 2)  # dimensione proporzionale al grado
    node_trace = go.Scatter(
        x=node_x, y=node_y,
        mode="markers",
        hoverinfo="text",
        text=hover_text,
        marker=dict(
            size=sizes,
            color="royalblue",
            line=dict(width=0.5, color="black")
        )
    )
    return edge_trace, node_trace
frames = []
for anno in sorted(grafi_per_anno.keys()):
    edge, node = plot_graph_plotly(grafi_per_anno[anno], pos)
    frames.append(go.Frame(
        data=[edge, node],
        name=str(anno),
        layout=go.Layout(title_text=f"Collaborazioni tra autori – {anno}")
    ))
fig = go.Figure(
    data=frames[0].data,
    frames=frames,
    layout=go.Layout(
        title="Collaborazioni tra autori nel tempo",
        paper_bgcolor="white",
        plot_bgcolor="white",
        xaxis=dict(range=[-1.1, 1.1], showgrid=False, zeroline=False, visible=False),
        yaxis=dict(range=[-1.1, 1.1], showgrid=False, zeroline=False, visible=False),
        updatemenus=[{
            "type": "buttons",
            "buttons": [{
                "label": "Play",
                "method": "animate",
                "args": [
                    None,
                    {
                        "frame": {"duration": 2000, "redraw": True},
                        "transition": {"duration": 500},
                        "fromcurrent": True
                    }
                ]
            }]
        }],
        sliders=[{
            "steps": [
                {"method": "animate", "args": [[f.name]], "label": f.name}
                for f in frames
            ]
        }]
    )
)
fig.show()

# %% [markdown]
# ## Secondo grafo
# Creazione del grafo per centralità di ogni anno che mostra la relazione delle collaborazioni tra autori delle varie pubblicazioni con il nodo centrale
